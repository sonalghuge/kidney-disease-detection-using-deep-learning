# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img
from keras.utils import img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPool2D, Dense, Dropout
import matplotlib.pyplot as plt

import numpy as np
from skimage import transform
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
import seaborn as sns

import splitfolders
# Out:
# C:\Users\SONAL\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
splitfolders.ratio(
    "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone",
   output="./dataset",
   seed=8,
   ratio=(0.75,0.12, 0.13)
)
# Out:
# Copying files: 3705 files [00:52, 77.67 files/s]

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
valid_datagen = ImageDataGenerator(rescale=1/255)
test_datagen = ImageDataGenerator(rescale=1/255)

train_dataset = train_datagen.flow_from_directory('./dataset/train',
                                                  target_size=(200, 200),
                                                  color_mode='grayscale', 
                                                  class_mode='categorical', 
                                                  batch_size=100,
                                                  )

test_dataset = test_datagen.flow_from_directory('./dataset/test',
                                                target_size=(200, 200),
                                                class_mode='categorical',
                                                color_mode='grayscale',
                                                batch_size=100,
                                                shuffle=False
                                                )

valid_dataset = valid_datagen.flow_from_directory('./dataset/val',
                                                  target_size=(200, 200),
                                                  class_mode='categorical',
                                                  batch_size=100,
                                                  color_mode='grayscale',
                                                  )

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=train_dataset.image_shape))
model.add(MaxPool2D(2))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPool2D(2))


model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D(2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D(2))


model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPool2D(2))
model.add(Dropout(0.38))


model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPool2D(2))
model.add(Dropout(0.38))


model.add(Flatten())
model.add(Dense(512, activation='relu'))


model.add(Dropout(0.5))


model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 354,532
# Trainable params: 354,532
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
METRICS = [
        'accuracy',
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall')
    ]
    
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=METRICS)

# %%
Info = model.fit(
                 train_dataset,
                 validation_data=valid_dataset,
                 epochs=5,
                 )
# Out:
# Epoch 1/5
# 94/94 [==============================] - 381s 4s/step - loss: 0.9976 - accuracy: 0.6093 - precision: 0.7381 - recall: 0.4571 - val_loss: 0.7724 - val_accuracy: 0.7259 - val_precision: 0.7981 - val_recall: 0.6280
# Epoch 2/5
# 94/94 [==============================] - 299s 3s/step - loss: 0.6723 - accuracy: 0.7447 - precision: 0.7941 - recall: 0.6802 - val_loss: 0.3591 - val_accuracy: 0.8881 - val_precision: 0.9032 - val_recall: 0.8693
# Epoch 3/5
# 94/94 [==============================] - 298s 3s/step - loss: 0.3143 - accuracy: 0.8827 - precision: 0.8946 - recall: 0.8695 - val_loss: 0.1479 - val_accuracy: 0.9504 - val_precision: 0.9534 - val_recall: 0.9464
# Epoch 4/5
# 94/94 [==============================] - 294s 3s/step - loss: 0.1622 - accuracy: 0.9450 - precision: 0.9475 - recall: 0.9421 - val_loss: 0.0576 - val_accuracy: 0.9826 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 5/5
# 94/94 [==============================] - 289s 3s/step - loss: 0.0988 - accuracy: 0.9668 - precision: 0.9682 - recall: 0.9653 - val_loss: 0.0314 - val_accuracy: 0.9866 - val_precision: 0.9873 - val_recall: 0.9866

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(Info.history[met])
    ax[i].plot(Info.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
predictions = model.predict(test_dataset)
# Out:
# 17/17 [==============================] - 25s 1s/step

# %%
diseases_labels = []

for key, value in train_dataset.class_indices.items():
   diseases_labels.append(key)

# %%
def evaluate(actual, predictions):
  pre = []
  for i in predictions:
    pre.append(np.argmax(i))

  accuracy = (pre == actual).sum() / actual.shape[0]
  print(f'Accuracy: {accuracy}')

  precision, recall, f1_score, _ = precision_recall_fscore_support(actual, pre, average='macro')
  print(f'Precision: {precision}')
  print(f'Recall: {recall}')
  print(f'F1_score: {f1_score}')

  fig, ax = plt.subplots(figsize=(10,10))
  conf_mat = confusion_matrix(actual, pre)
  sns.heatmap(conf_mat, annot=True, fmt='.0f', cmap="YlGnBu", xticklabels=diseases_labels, yticklabels=diseases_labels).set_title('Confusion Matrix Heat map')
  plt.show()

# %%
evaluate(test_dataset.classes,predictions)
# Out:
# Accuracy: 0.9950678175092479
# Precision: 0.996178367524452
# Recall: 0.9899888143176734
# F1_score: 0.993000107641581

# %%
model.evaluate(test_dataset)
# Out:
# 17/17 [==============================] - 13s 747ms/step - loss: 0.0159 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951
# [0.015872251242399216, 0.995067834854126, 0.995067834854126, 0.995067834854126]

# %%
model.save('model.hdf5')
